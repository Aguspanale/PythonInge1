# %%
import requests
import fitz  # PyMuPDF
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import LambdaCallback
import sys

# Download the PDF
url = "https://josefaruiztagle.cl/wp-content/uploads/2020/05/cuentos-borges.pdf"
response = requests.get(url)
pdf_path = "cuentos_borges.pdf"
with open(pdf_path, "wb") as file:
    file.write(response.content)

# Read the PDF
doc = fitz.open(pdf_path)
text = ""
for page_num in range(len(doc)):
    page = doc.load_page(page_num)
    text += page.get_text()

text = text.lower()
print('Corpus length:', len(text))

# Create a mapping from characters to indices and vice versa
chars = sorted(list(set(text)))
char_indices = {c: i for i, c in enumerate(chars)}
indices_char = {i: c for i, c in enumerate(chars)}

# Prepare the dataset
maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

X = np.zeros((len(sentences), maxlen), dtype=np.int32)
y = np.zeros((len(sentences), len(chars)), dtype=np.float32)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t] = char_indices[char]
    y[i, char_indices[next_chars[i]]] = 1

# Build the model
model = Sequential([
    Embedding(len(chars), 50, input_length=maxlen),
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    LSTM(128),
    Dropout(0.2),
    Dense(len(chars), activation='softmax')
])

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.summary()

# Helper function to sample an index from a probability array
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-7) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# Callback to generate text after each epoch
def on_epoch_end(epoch, logs):
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    start_index = np.random.randint(0, len(text) - maxlen - 1)
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(400):
        x_pred = np.zeros((1, maxlen))
        for t, char in enumerate(sentence):
            x_pred[0, t] = char_indices[char]

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, temperature=0.5)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# Train the model
model.fit(X, y, batch_size=128, epochs=60, callbacks=[print_callback])
# Out:
# Corpus length: 109278
# Number of sequences: 36413
# C:\Users\agusm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 2.9932
# ----- Generating text after Epoch: 0
# ----- Seed: "memoria; me entorpeció el temor de multi"
# memoria; me entorpeció el temor de multiras
# lay degra
# de pirer alpurior, lo en hanile
# una par el
# dapuris parer en vermiba en me
# perpomro
# qui de el
# sanpuisa, de de muociar
# enla dimra amerda cura, en de sapivos y
# parira la la mapura purar por
# prastar de parra
# elpura de
#
#
#
# de
# nabariro la la
# tarparaco el ponpira de puna en elira pora ra porpiras, des el a demper
#
# lal debriardo
# que puroria, la pan parre la pomerpera poria de
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 50s 165ms/step - loss: 2.9921
# Epoch 2/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.2682
# ----- Generating text after Epoch: 1
# ----- Seed: "quiel, de un ángel de cuatro caras que a"
# quiel, de un ángel de cuatro caras que al la escero
# oratia de la dentenva en la pracio que campatió de en mentisces es en estera pententente en en es en la pribrabia de hentio, en trantos, en las min hontiba y de prapia henter en pentis
# esa se el las sunos de de las ses en este arbestarte se
# en poncuntentes, en es en es la estentes antera en estotienta de
# 2en si mentera es es en santar que en nobentes que es estertes de en en la min
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 47s 164ms/step - loss: 2.2681
# Epoch 3/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.1355
# ----- Generating text after Epoch: 2
# ----- Seed: "e alquimistas y
# cabalistas, nuestro con"
# e alquimistas y
# cabalistas, nuestro con
#
#
# los o son el labía perenta esa distoría que de
# repurlilgo ses
#
# la embres de la terseda de peramo de suentre me la prepleción de la suedo los a la la al una de tambre cesciertado
# no la de chabia a la pregurio el el la desperdar de la despotos y la estorio de sue de la otra el le sue rontrepa de la había de la mestra prose para la del
# tardibión no de le me seguiero de la
# tapía y con una p
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 2.1354
# Epoch 4/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 2.0233
# ----- Generating text after Epoch: 3
# ----- Seed: "
# terror: ahora que he burlado a richard"
#
# terror: ahora que he burlado a richarde
#
#
# esa un de la puera
# cartar y el pritergenco la bordable en el humo con se el entercado.
# la paría la a vitoro que mi escerque la tante de un de la resuerrosas y la addiento de la de con que y
# atro su de perse pristinos de bendió, había sarden, si lo alephabras a la combre a un de un espestor por en la casa esta solo lo indudiento me de sugernante. pero de la costra de un puentones de un me
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 2.0233
# Epoch 5/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.9467
# ----- Generating text after Epoch: 4
# ----- Seed: "ito)1 están abiertas día y noche a los
# "
# ito)1 están abiertas día y noche a los
# obra su huemprecisio y vompres, en la histar puede a un puede palación y precitos
# de la herentico a la conterinta
# de tardillos de la acularia por la cara en el especha de sin
# se
# eleste de la encentines. la el suente y la enela trasmes parea de las
# sintiniciones de un conterro y en la escribiles, la casa una unas sicos y preciero recorre en la ligiro la collado de la el palas a la en la vil pr
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.9467
# Epoch 6/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8752
# ----- Generating text after Epoch: 5
# ----- Seed: "me aclaró que su libro cantaría la frate"
# me aclaró que su libro cantaría la fraterado en el sendería mi primo de mi printo de bifasado de un casa,
# había amoria con bien dilo, sin llevicia la solo tiera me tembién mi todo la torres consitilaba en el contrastaba la imparión de la condidia de la hiere diel trandimido de
# labre que estaba el vel colvadado el cunto de la colino a la pana se dijo a compario de la había disticas a mi condició que es un concoderio,
# de la especia sin
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 160ms/step - loss: 1.8753
# Epoch 7/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.8158
# ----- Generating text after Epoch: 6
# ----- Seed: "eve y sin duda el más pobre, pero no el "
# eve y sin duda el más pobre, pero no el insitiros de la indiados de la basas que algún de una matoria de minudo al primeras de misterial de mundor de los muras argentino de su podiero de biente las con el mil trotor de la seramente. el presivo sin misticio que
# se paratamente, de esa que sin
# el el catales alguiero de alepha es el almaro con una por el printo de la escreguia que que el cono de la
# talera de la malenta,
# -con lo he y ing
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.8159
# Epoch 8/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.7745
# ----- Generating text after Epoch: 7
# ----- Seed: ". deussen y mauthner hablan de una bolsa"
# . deussen y mauthner hablan de una bolsara que represión. no la que esce esa
# respordena. que temor es propió el conociente a los monos amoros de los homestas y serraria de su pareción de desconderia de los conomimas. que lo con el hombre la oscre de la otra todos los poescia de la otra y es el vez el casi repuerdo de la visto por los sin de tiempo. casi
# se la
# casia de la cara la
# insticia al minto me deperido de
# pierra de visto ince
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 47s 163ms/step - loss: 1.7746
# Epoch 9/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.7417
# ----- Generating text after Epoch: 8
# ----- Seed: "as cuatro, “para tomar juntos la leche, "
# as cuatro, “para tomar juntos la leche, me hombre que el primerable por la carra del carrendo que el prence entre menos nombres
# anciales. acaleral de la ferdicada y con el de la hestica. pero el otro que es que lo falrica y bente, pero se esperio con la imperiora y la historia de escredino, la encerió que se habre una obra la mandera y el cartar que no hiz su primo la parteción de silbición de la escribida de la clara de la carrero, el
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 160ms/step - loss: 1.7417
# Epoch 10/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.7176
# ----- Generating text after Epoch: 9
# ----- Seed: "ible
# pululación. no la pululación de lo"
# ible
# pululación. no la pululación de los tenoras de para el deraba mi vereente, en el alsinos de que el primera, lo despuésa de una proscuero está recuerdo la casa galabra de unas muerta estar de la parce, mi casa esa dice que ese no es la minatica que en la escanar esa estaba persar que el argentación de la desperió en los coras en el perena. el carales, en la mententa en la prosas me apacia es barenta. en la estaba en el casa de la c
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.7177
# Epoch 11/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.6805
# ----- Generating text after Epoch: 10
# ----- Seed: " o una justa
# noticia habrá millones de "
#  o una justa
# noticia habrá millones de la pasaza del después de la tranges de que te insusino. en el la vero de la escarda de una
# caron de una había condicida y que en una contes del sucho se en el seguerto de la dijera, recorder que se en la
# resumira la después, de la verse, en la cirtación de la dijo ten mandran de su hombres
# singuerra la mandaré en una antibar que y sin la estaba en la tracto gerrado, pero a sin la hilera que ese
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.6806
# Epoch 12/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.6705
# ----- Generating text after Epoch: 11
# ----- Seed: "o disuadieron
# dos consideraciones: la c"
# o disuadieron
# dos consideraciones: la concada de la casa de la entende de espanaron precisan de la noche de la cara, por la estadia las muerte y la casa y sendición que se esa amoridad de la estadica el mestro los jegras concontendero se delio que no es para no he la menora de randir la letra sin la
# lecho de la sigleró
# sin
# el uno increóa con la estaria del casa albancio de la
# casa la concaba de la pensa después y
# en el un carramen
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 1.6705
# Epoch 13/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.6597
# ----- Generating text after Epoch: 12
# ----- Seed: "ecirte cosas que no puede saber un desco"
# ecirte cosas que no puede saber un descondidades, sabía sin del cartos a un cintar de la infinicia como todos los de la eral es
# poelaba en la fal, con la verso contradicario del puedro a la pasado, pero en el pasas y todos los trasmo la es un segundo perdiento, en la humera un laboran de la presiones de la parresa y vi con la terrota de un pasaba en los posibilos y la por la ferrer al caro perdiano un palabra regue una entraba corridad
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 1.6597
# Epoch 14/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.6373
# ----- Generating text after Epoch: 13
# ----- Seed: "adivino
# [minicuento - texto completo.] "
# adivino
# [minicuento - texto completo.] se mura el alber y descubros
# de bontes en la misma entre
# otra, la casa y en los salas por la obra. los prinestiero en la luna y esas en la menora laboros en el carro que me dijo que esas partitos, que se pensa de labo de todos los cartos de las muciero de las me delino y recuerdo de un dobido y lo un desconcombre la menado
# la veza a la sola torre con la descirto por la
# librara que mi cuentra d
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.6374
# Epoch 15/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.6197
# ----- Generating text after Epoch: 14
# ----- Seed: " del
# alfabeto.
# pasan trescientos años"
#  del
# alfabeto.
# pasan trescientos años de intampración de las versario de la primistica no vierdo de una indictar es la lecho había su ferado
# la espasión de las había sentor y la foncianda de la caria es una mano sus memora la estravación de está
# cada un temor intrincia por la instaria el tamplatir de por la saligar y la columpló de la mespica de la muerta a la historia la
# libra de la espalca de sin la pasis murió a muy
# matal de l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.6198
# Epoch 16/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.6118
# ----- Generating text after Epoch: 15
# ----- Seed: "la cómoda. lo abrió; debajo del retrato "
# la cómoda. lo abrió; debajo del retrato me he descubido prori sucidad de la unuerno de indigera de la mespidie de la hombre de nuesto de ese vizar
# su la primos la tiempa que no me he
# sieto la falsa. mi por ese carro de la meredad a con de ese orte de carronio de su muerta, la dije que es el alato y su primirado y de
# cuarto por la caria proleción y se descreo que había la indigura en el numero, con las estaban estaban verrandes a los
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.6119
# Epoch 17/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5862
# ----- Generating text after Epoch: 16
# ----- Seed: "e el todo no es mayor
# que alguna de las"
# e el todo no es mayor
# que alguna de las libros de rescurditor es la atragera en un se el cosas y con mari reconocidas el maror de matón y sin
# laberinto de todos los peristinos, las desceden algar y mucha gente a la serecia esa incuerta que se se he es la meredió que esos la pasaba de fenera de albo es que tenci de la casa previstada de la prosentado un todas los
# pasados corregundes en los como para
# deliranero de los eramenos de una
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.5864
# Epoch 18/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5993
# ----- Generating text after Epoch: 17
# ----- Seed: "able de tan rico y tan nítido, y también"
# able de tan rico y tan nítido, y también de la versica,
# el ríor un de la palabra en la venidad de la menos había contertar de la pareción de las ojos mil de la pasación de la tras en el levón de la lintada
# muy los de los argentinos todas los de la mespreción de bibliona que había de la de piembre de la carto concerdente que es prumer la mescenda en el tiempo ya muerte están de un primito de la cariar el primer el se respudijado el sol
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 1.5994
# Epoch 19/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5836
# ----- Generating text after Epoch: 18
# ----- Seed: "réplica tripartita del otro.
# me dijo qu"
# réplica tripartita del otro.
# me dijo que una cara y la confición de la basa las que se acasado que lo de sus había un esperido la cara de la fenera de la caramente en el casamente de la sentición de me no palabra.
# “el albo de la menos la madre, nuestro ahora. lo alcunar el casas de la oblaró en el seguir en la o la descubrita de la prestar de
# las descordentes
# con mi prometo, desde una estración de la posiba de esa demastica sabía. m
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.5837
# Epoch 20/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5810
# ----- Generating text after Epoch: 19
# ----- Seed: " de ts’ui pên, todos los desenlaces ocur"
#  de ts’ui pên, todos los desenlaces ocurseridos y en el corrado la parto con la carlos de la cara tinciales primera en la provistante en
# carlos del catror de la sinpuen recretaba con la obla de la
# casa de los de ese insistrafica de especto de la perso a la transparatirado de la instante
# estaba concente y alguna de los cosas la situlino y y la puestale en una de suerte
# de caralle de los de alcino de pombre por el de la fel escritoria
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5811
# Epoch 21/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5867
# ----- Generating text after Epoch: 20
# ----- Seed: "
# libros orientales y occidentales. reco"
#
# libros orientales y occidentales. recordó que vorde un laberinto de la trantal.
# en el aleph de la escricto al docto un largo que la enteria reperdibión de la muerte, de
# la menos, en la sola padre y a un presto de la hacía de la arves muy antes de la de la escrite de la muriar. en el sólo de la después lo la primera especie.
# con el aleph que su impronución de espeche de la terrado en la
# parecia zunz. ahora los había antes de canden
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.5868
# Epoch 22/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5717
# ----- Generating text after Epoch: 21
# ----- Seed: "isis combinatorio, con la tipografía y c"
# isis combinatorio, con la tipografía y con casa de cara y pareciente a una jediatación de
# siguiente para un puede estaba vistolla.
# algunas de estaba en la correcor ese procicior torrencial, al minaciones de las desparabanes
# posibias de las desantobas del acoparía no es la hombre de la palición es probide me dejor de la espalabra de la menora confincia mil de los de su enqarden, con las caras eses contragas matos y segundo
# ese en el
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.5718
# Epoch 23/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.5839
# ----- Generating text after Epoch: 22
# ----- Seed: "ada es humildosa -explicó-, pero si la l"
# ada es humildosa -explicó-, pero si la letra antes de la pasa todas la espejación algunas la carla de la estrición de la fuerra la amoria muy precisión,
# en la parecial de una versa. lo confitivamente ahombre el
# pasajo, que se alguierto y el casor en un
# venera de la contestión de un espalda. en la confunición de la monteción de la casa de la intez. mi mano de las espejaba algreciando de una salta de un promer que san un laberinto de l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 1.5840
# Epoch 24/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.5664
# ----- Generating text after Epoch: 23
# ----- Seed: "pondió con mi propia voz un poco lejana."
# pondió con mi propia voz un poco lejana.
# lo minura de un paldea y la ditos de la casa del temor desparación de un verso al irrigiar y el casio de los de la milledo es en el de la
# invitera que el color de la atras de todos los del tiempo de la ternado la versada un patio de la cosas están del aleph.
# atrecho de la laberinto de la contentar el cologo era la fuera de la para de la obra de que ese espantada más de la muerto de su primera
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 163ms/step - loss: 1.5665
# Epoch 25/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5924
# ----- Generating text after Epoch: 24
# ----- Seed: "te como una estatua, pero ese hombre ava"
# te como una estatua, pero ese hombre avano, los singulos manos de
# un espacio de los temor mucho ahora el portente de la serrer contestado con la mespeción, lo alto de los noches de los hombres de la casa de sigui no pedigado el
# ensoctor de la interenóa que un visto a la procio de abelixos de los los laventicos del aleph en el después de los
# discisible de la maltación de los periosos de mi los dias de su pondencia en los de mi interdi
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 161ms/step - loss: 1.5925
# Epoch 26/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5938
# ----- Generating text after Epoch: 25
# ----- Seed: "venir con el pretexto
# de la huelga… abu"
# venir con el pretexto
# de la huelga… abulante de
# legre en la con la
# alcarza y a los el primer lo intedios la espejida,
# a los antimos y la escribica a aguas no con el de un pasado los escalas de tiempo, de la únumo emma
# calliga de la suela después en la pareció con el insuendo del muerto en un solo estard el puesto y la escribido que se el temor de la
# si lo perdición de ventara y en la especia con mi descaro de la posibión de la des
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5939
# Epoch 27/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5913
# ----- Generating text after Epoch: 26
# ----- Seed: " había un aleph. aclaró que un aleph es "
#  había un aleph. aclaró que un aleph es un laberinto de sus probimos y sin dijo:
# “el siglo de la casa de los pasas tres
# confideros los
# delicas propios de su instanda a di fansación de la puestales de una bestidad de la cuenta emperidad de veraramente de inclinidad de plan de nuego me dijo que había en el destiere para la vidad. cada probres en el aleph. con el ventano de sus
# galarios de galaz melalas de ese instinte en el aleph. en
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5914
# Epoch 28/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5781
# ----- Generating text after Epoch: 27
# ----- Seed: "ra un loco. todos esos
# viterbo, por lo "
# ra un loco. todos esos
# viterbo, por lo a acapo en el catracerno con el de la primera perso como los cuartos del capí)
# algar. a de la falerga de los hombres de tambor de sus de la tras concesa. sin de la bestración y la ocurrado en contendernado me demora, al falseo. para la
# incuerda he
# dije:
# se a falephe, en el capínero de la casa y tenerán de una faceda, pero la obligara a la tarro de
# denóritado de aleph. emma para testrajo, pero
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5783
# Epoch 29/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5659
# ----- Generating text after Epoch: 28
# ----- Seed: "caóticos. la
# familia, como usted acaso "
# caóticos. la
# familia, como usted acaso de teligro el como el recordó su precio de es su al oír todo la flitar de la
# viza en carro propios de muche no sabía me dijo que se avelición de la
# guerr tor el catille trendido es la guarda
# nortial de plandíciente
# que matan de su
# templo de la
# sietra de la respurado
# que resundió en el prebertió el de la ville un verba había entuerto de la centente de la verenta de mi confistando la vertada
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5660
# Epoch 30/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5977
# ----- Generating text after Epoch: 29
# ----- Seed: "mi enemigo, en otro mi amigo. si
# se res"
# mi enemigo, en otro mi amigo. si
# se respalder con de la propalidad es el casa de la vistorica mil sal los había encuerdo que esos de ese tiempo algunes de la escribir en un piema del pasajo de la temor la casa de los
# indicientes
# de la caralla para propalar de la fuerta de la primera te
# alumera.
# los
# agreguidos
# a su padre de la pierta alguna a la carta de la dijeo. la vistorica propio de beatriz
# de la cara un puesta transcerro de
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5978
# Epoch 31/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.5799
# ----- Generating text after Epoch: 30
# ----- Seed: ": a) hablar con álvaro y decirle
# que el"
# : a) hablar con álvaro y decirle
# que el temor salígar a los habían de ocuas de un visporio, y no lo acurdado en el pernecto de los prometos en la casa mi sigla de un sombro al oía una enquio con las de la casa de los tabres. los argentinos
# la mustió
# de la carse con el caso
# de
# la constancia resende que se abuante a la invitado en un piemo a mi en el prímero de la
# primo mano de la obra y los malos de la increí la preciena el desespe
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 46s 162ms/step - loss: 1.5801
# Epoch 32/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.5977
# ----- Generating text after Epoch: 31
# ----- Seed: " de los números transfinitos, en los que"
#  de los números transfinitos, en los que esa había algún del aleph el mestomos y contes de las ventamentes de la pormana de la cara de la relicada prosiguió que por el espejo y los hacías en el pasajó de la cara y
# discapicios de la casa de la invititaba de la casa la trivaz sin duegu hacía promitos y el temor es un latín libros y perdisticiomente de los
# fincios de un mucho acucaba de conocullación de
# puedre me dijo que preciso y
# not
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 831s 3s/step - loss: 1.5977
# Epoch 33/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.6029
# ----- Generating text after Epoch: 32
# ----- Seed: "r que el mundo inferior es el espejo y e"
# r que el mundo inferior es el espejo y en el capita y
# te será de los confensas de la carra y a la placaba de tras
# tosas tostos de la rejación y el laboro de los de la mismo es la cara guales de la casa de la recor para los desendados del ríomo con la seraria que me siempre de complerarme la ocha de la carta a los procios de la modre apararó a los argentinos, la bibre de la carria de la bibinada y los por la sina trans
# rerecoro desde
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 47s 163ms/step - loss: 1.6029
# Epoch 34/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 1.5963
# ----- Generating text after Epoch: 33
# ----- Seed: "s ineficaz; aprovechaba, hasta
# hace muy"
# s ineficaz; aprovechaba, hasta
# hace muy enemicio con algún
# del minura
# calleáneeció el pasajo de la encarga y la
# adrerada la entencia persgado en el segundo.
# respumido que lo con le entorde a la intrivicación que se descrigido, el descuver en al de la concerma de estaba una de iniciar de un
# de
# mediatos de los cosas omas, su
# los palabras de la casa tuvidad, no me está en el temor apiosa vitán con el campo, en el nuce, en la antinu
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 48s 167ms/step - loss: 1.5964
# Epoch 35/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.5824
# ----- Generating text after Epoch: 34
# ----- Seed: "esa idea. ciertos ejemplos que aristótel"
# esa idea. ciertos ejemplos que aristóteles de falseona los menos de verso se me dijo que me dejor en el un de la
# escritar con el cambrifica
# con la imagen, de bando y la casa tel vorrenció de la escritar y la casa, el antes del numerable con el pasarrín de la sibinica el sigre de inunidad, a al acatalles de la mestica. la
# balga a la ganar en la plación de testama y a fue el como esos al prista confances de con la casa de la noche me d
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.5825
# Epoch 36/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6134
# ----- Generating text after Epoch: 35
# ----- Seed: "un solo balazo en mitad del pecho rubric"
# un solo balazo en mitad del pecho rubricas puesto de los hibro. el fel. es el verso el perneo de la charilla de la primbrara tomo otra
# intarseteda.
# es un
# devino de las noches a la sola esestima de la noche de la molación de la litira y con las rifinos había era la carsuara de la cara de la cerrar y el comos el astro de que puertar que esa me dijo:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# era sin el diccionerio de un carazo
# de la mesta
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6135
# Epoch 37/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6006
# ----- Generating text after Epoch: 36
# ----- Seed: "fundadas por nómadas es indispensable el"
# fundadas por nómadas es indispensable el decanosaterna a la oblana conferiana con el
# siglado el alto había sal de sendía del catorce, el meno, al aunía otros, al oíante saló la sincia de siempre al capítil sin de la sala espacia de tiencrablió la balabara casa los de la
# descrepuraba la primbia y casa de la monte provisió el de espaciones de la pasa muy la trecia de los recorderoces, pero la primbra y la
# folscana.
# la casa flana de un
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6007
# Epoch 38/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6002
# ----- Generating text after Epoch: 37
# ----- Seed: "ichard
# madden.
# “-el porvenir ya existe"
# ichard
# madden.
# “-el porvenir ya existe la recardenta de la
# terrica estada de la tierro el capitán; con el carto de la pasaría zungino de
# la respundación de la mibre que el laberinto de la fazación de la estada es todo la pierta de la casa un solo contiero concubar de la casa de la concera con dos abulos de mi constaba a con el
# acarte no si decinto de un himero con las concustos son un cadres
# de la resar tengo la gacela y que en el
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 45s 157ms/step - loss: 1.6003
# Epoch 39/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6140
# ----- Generating text after Epoch: 38
# ----- Seed: "eer y la rompió.
#
# 28
# referir con algu"
# eer y la rompió.
#
# 28
# referir con alguna es las dicidos y la declaba
# el capítico me se había en el indería el constagarmos de ese sin de la cara de rostra de los transcundes sin dunar alcivera que había provisiós úntica. lo oscerdor de la
# pelabra a azico es un pincionas de la errecar y lo primperiartistrofición, que había el te dejor el todos los compares de
# vierto. un primer su varlas
# de los las piertos de la elilemone antes de l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6141
# Epoch 40/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.6102
# ----- Generating text after Epoch: 39
# ----- Seed: "a se confundían las ramas, la luna baja "
# a se confundían las ramas, la luna baja de la pasacho. nueste se por la vistora toda la bueno sal madden.
#
#
# 19
#
#
# 1
#
# 13
# el
# incuerdo que se había pareciente dicción de
# todas la fedriciones de los sarges, en el
# después de inverlitar a la obra ya indencial, ahora, con el sé de la noche
# tente de
# la el abolado por el segundo de la
# verso regentí que es dilos de la biblioteca antes de la casa de una delico aferado para la
# versar
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 45s 158ms/step - loss: 1.6103
# Epoch 41/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6154
# ----- Generating text after Epoch: 40
# ----- Seed: "izo pedazos el billete y guardó la moned"
# izo pedazos el billete y guardó la moneda
# la oblada a mi escritura, la escribir para un palabra, con el segundo, la voz la vistar.
# la corta transma no salbo el sendido una de la
# será en el de la pisi(no no en el casa de la historia, pero veilidadera de la que la sola vistora te jardín de la resendónica con el laberinto.
# el decerd con reperdirló, está en la intelera de una de mi de la calacia.
# cada palabra y a la grabillo y
# el podi
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6155
# Epoch 42/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6175
# ----- Generating text after Epoch: 41
# ----- Seed: "ro
# rayó el cielo gris y ciegamente lo t"
# ro
# rayó el cielo gris y ciegamente lo trendar de la matada el murio del te orro de infinito de la se de la caral, al recordado el aleph de los versamos de la he es agraverana y la de su trabajor tarde de la matale mil recordaba que es por una emparia en la abres de caromlaba propasios de los completios de su vera a los
# pállinosas de la
# ocurriga de esa rotreción, pero el viempo de terrado a los de la mañada del atrobable una casa de l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 154ms/step - loss: 1.6176
# Epoch 43/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.6130
# ----- Generating text after Epoch: 42
# ----- Seed: " en cada uno
# de los meandros de su infa"
#  en cada uno
# de los meandros de su infatigado de la cara, pero el oral de la obra y noche que preverdable.
# antivial de la obra la vida con la lana y gertidad, pero las palabras, un pasajar que había en el primer
# se el temor de la creaa probida que de la cara y lo insigilo de casi antes de la enteria.
# los de pierte nuelvo al veo un palabras, mi alvoro con la concercidad, el día perficurar y el otro, el aleph y y en el deverales y la
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 154ms/step - loss: 1.6131
# Epoch 44/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.6381
# ----- Generating text after Epoch: 43
# ----- Seed: "e la entrada
# central. bajé con lentitud"
# e la entrada
# central. bajé con lentitudo, en el después que ese amaderan de los recuerdos de la casa el siguiente de la tiempo de los trasmos por la recierdad,
# que si
# y la indiga, que la palabra era
# inexitos argentino dos agres, en la
# jorga la casa por el alco que el primeras que es admente, el arcentimo a la obrara de sender, pero el muerto de los murdas viguloso de la oscuria era el era de la especia de la urreado
# la parecia era
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 154ms/step - loss: 1.6381
# Epoch 45/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6239
# ----- Generating text after Epoch: 44
# ----- Seed: ". naturalmente, hay varios desenlaces po"
# . naturalmente, hay varios desenlaces por la despedimara el acardenciana una
# tecar te recuerdo la pasación de otro de la vistora de la
# invitió el me dije que ese visto de un pasado el en el poema de la loriga de la meridadera de esa estraba en el parecial, ese preciso.
# el conocíriciones de la casa la calas de la escedio que ese la palabra de verrodo de la ocurricidad, en el algaría perdiento se parecir la
# vistoria,
# que yo perdiendo
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6240
# Epoch 46/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.6209
# ----- Generating text after Epoch: 45
# ----- Seed: "lfabeto de la lengua sagrada. su aplicac"
# lfabeto de la lengua sagrada. su aplicación de su sabía a los desvios de
# nueva es el pasalle. en la fatiga de la especia del albar de un pierie, pero con otros los despedió es después y con la casa de la encretar es el preverlido
# el aleph de la casa de incargante de nuestro es el case de la desperición de la concumbra y de los suplicas de la
# visto de la oficica de los recordidos de borta de albert de con mi paene de su palabra y a lo
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 45s 157ms/step - loss: 1.6210
# Epoch 47/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6136
# ----- Generating text after Epoch: 46
# ----- Seed: "dénticos a los de la casa en lanús) y de"
# dénticos a los de la casa en lanús) y de
# su puede será alguna se una casa y pesar a los serenados a un pielfición y de los sumos pásticos de sus
# veliz temor un hombre lo montano de la cirtica
# de consustición, estaba por el alephar y el temor a
# la había en los libros de
# los que puede me dijo que puede mi pasá de
# la recuerda con el preventán es la cara el centra.
# así, lo pronuman, por un pelación de indicidad de los tiempos de la t
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6137
# Epoch 48/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6248
# ----- Generating text after Epoch: 47
# ----- Seed: "itores. (no hay tales cenas, pero es irr"
# itores. (no hay tales cenas, pero es irres
# sin veré el carrigo por un de la intristeria muy estismos podías para manos de la cimario de la cierto de la monamente malon de un atribar a su podía para al partar de la cara ol primitaó me feridad de muteria infinita. con la inventar de la
# fincial de la de la primera de la teminado la cara, de la carlo de la casa, de la carlos de con la oscabrarlado el segundo el veiliz aculado a los saltan
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6249
# Epoch 49/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6458
# ----- Generating text after Epoch: 48
# ----- Seed: "que declaran que en egipto hay
# una pare"
# que declaran que en egipto hay
# una parecir, pero personador que esa oras y de la carta en la alumora de la despedima con el sol del sobre de
# temor de
# la conterlación de para el hacía en rigono de me primo y para visil. en el detrar en la carta de puerta carta y el segundo de los especieros de los desde ese perincio y la paralía en una puesta y de la consetición de la patolara a mi tarde le del probretió
# el creía con el antes de los
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6458
# Epoch 50/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6262
# ----- Generating text after Epoch: 49
# ----- Seed: "tante, pensé que richard madden había pe"
# tante, pensé que richard madden había perletas,
# no es contrande
# el temor una de los que es una esa cental de una metras emma
# en la palabra de otros
# habíamos de la candeción de obligar y carlos de la que experar y la palabra a a balapación de la pierta del carres de su reguertos ochentando
# escribura, y la recación de todos los tierro, ahora, la patica,
# mano y la conterminada
# la cara y el todos los las priverios de oblar
# tuvo de t
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6263
# Epoch 51/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6447
# ----- Generating text after Epoch: 50
# ----- Seed: "eas de la espuma que un remo levantó en "
# eas de la espuma que un remo levantó en la especiente no la cirmena de la pasado de la histo y calleían de la pasa de la menera a la flar estaba por la cirmo de la respuraba el falemo de una bifula estaba cada ya
# diccian de la cara y carlos,
# al in
# la priminar de la obras de la pasa y de los lechos,
# al cada fuenes admos
# de la cara de morigio de la infuncia con la había salo por el muertos de la obrar es del carsetos la descuerdaa de
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6448
# Epoch 52/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6439
# ----- Generating text after Epoch: 51
# ----- Seed: " díaz.
# dos observaciones quiero agregar"
#  díaz.
# dos observaciones quiero agregaras en el alto y trabando
# en la noche de la carta de la pronta solo, en la contención de las precitos y los prosaras en la pregunta los cosas de las pasistes. en la una de los hombres de la indiciana y
# aalestido en que la merada de imperio de la minura contravo alguna a agregado una respundición de su pierre de su albert no saquía por un albert por a la paraca de la bremora de un que
# lo perdició
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6439
# Epoch 53/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6423
# ----- Generating text after Epoch: 52
# ----- Seed: "ía repetido con fervor, ahora lo recuerd"
# ía repetido con fervor, ahora lo recuerdo me recuerdo, por la
# pasia de la ora y la mismo de la respués de bansarda de los
# he oblió y en la sotana, pero recuerdo, a para luego de su debición y comprendera con el caollo.
# arronre, en la tierro
# del mismo de la carta de la terrera renotri de olvial en el pordenir de la recuerda el perse
# del casa de la biblio de la supués de una sera el capito por el el piempo a por un cipelabrable con l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6424
# Epoch 54/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6391
# ----- Generating text after Epoch: 53
# ----- Seed: "cuentro fue real, pero el otro conversó "
# cuentro fue real, pero el otro conversó la histora el silo promigado de la carla en el persó que es en la perse para al palabre con cararlas, de la obral era perfeccia de la casa de la biblicada de la de la candea o de la carlaccia de carregía de la laberinto de la estena de la carlatica de la tino galte a la femora incardia que me dijo:
# “buando en la escribir de oblaba en la carta de la icalle jarra a la piballe garrda no sal recupido
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6392
# Epoch 55/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6413
# ----- Generating text after Epoch: 54
# ----- Seed: "elo– también de nuestras vidas. quería d"
# elo– también de nuestras vidas. quería devicirse antes de la recuerdo
# el senderos de la primera toda me recordó en la carra el verencia de la obra temor. la esas difeción de burable con impeza de la obra
# la escada lo primeran argentino que esa obreción que permisto en la canción de cambiente la caparlo persuminación de la escapación de la cadre de la carta y carlas de la carlos de que el pasamro de la casa el seido y con el temor que
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6414
# Epoch 56/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6459
# ----- Generating text after Epoch: 55
# ----- Seed: " un
# hombre que reconocí corrió en vano "
#  un
# hombre que reconocí corrió en vano muy en la casa a los recuerdos de la primtua no me dijo:
# “recuerdo por el de la crima la cerrada de la carto a antes de la incondicado que había de esa
# ser un tema de casa de su casa mil para atros de la caria de amineo.
# el
# corpez se había invención las repliciar de una cana el conseratura y del casa y carlos de repué a la pámpica y al comprende la princia de morido de la cara de los
# primosar
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 155ms/step - loss: 1.6460
# Epoch 57/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6506
# ----- Generating text after Epoch: 56
# ----- Seed: "o sé la cifra de los libros que escribir"
# o sé la cifra de los libros que escribir de la casa de la cara el se primer estaban el todos los y cambios de la elsenti y la espezado de los de suel invisión de siglo de un solo el capo parecir el capito de su destibía a la pasa de los hombres y también de la con su pediente de la naturales de siglos por la casa constalar es una pasa de esa dijero que todo la confundia de la impensa de
# una de la casa de carres de la indición de un pas
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6506
# Epoch 58/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6470
# ----- Generating text after Epoch: 57
# ----- Seed: "grandes reverencias le digo: ahora
# volv"
# grandes reverencias le digo: ahora
# volvaración de la obrado en caso, con el de un alto de sus minvos. por el mesperen con el perdinio con una estadir podía
# del versarlo a los escaré entre
# también en la cara todo la vez el astito de acasa ristible que recuerdo de beatriz
# estaba de la verable la vez el desestentan a un propetino, la que el
# segunda vez el de un préche de una recordó en el aleph. dos partes de los carses de que su pres
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6470
# Epoch 59/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 1.6428
# ----- Generating text after Epoch: 58
# ----- Seed: " la
# vio hacer un pequeño rodeo cuando e"
#  la
# vio hacer un pequeño rodeo cuando en la tierra, a la para
# de la serancia de sus con el fuedo un alba y la vistoria de cuatro de las propilos con la
# galerable completo, en la a laberintio de una hora, con los canses de la pregunta de es se humo
# del pasajo y el nombre y los cosas tolos no había absugaría a veces de la espebliación y lo decuriento de
# dos freginidos de una terligado me
# dijo: sar se había sumiento de mi parte con l
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 156ms/step - loss: 1.6429
# Epoch 60/60
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.6503
# ----- Generating text after Epoch: 59
# ----- Seed: " del muerto.
# emma dejó caer el papel. s"
#  del muerto.
# emma dejó caer el papel. su primera, recordó en el pará los hombres a mismos de la prima lo incuré
# respredida a su piempa de la casa de la mestar el cerpido al carlos casa el percero no había noche de tiempo al espejo.
# con algú a todos los pormidos, había de la reperde,
# al carrar que el como por prosunció de una puede se que no en la otra de esa
# considado la
# confoción con una menora.
# en la cara mis atros
# antes
# algo
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 44s 154ms/step - loss: 1.6504

# %%
generated = ''
sentence = text[0: 0 + maxlen]
generated += sentence
print('----- Seed: "' + sentence + '"')
sys.stdout.write(generated)

for i in range(400):
    x_pred = np.zeros((1, maxlen))
    for t, char in enumerate(sentence):
        x_pred[0, t] = char_indices[char]

    preds = model.predict(x_pred, verbose=0)[0]
    next_index = sample(preds, temperature=0.5)
    next_char = indices_char[next_index]

    generated += next_char
    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
print()
# Out:
# ----- Seed: "
# 1
# selección de cuentos de
# jorge luis"
#
# 1
# selección de cuentos de
# jorge luis fresar es
# confertable la fegua y la sorronapica de quita y a una con la rescupía la perincia de la incircuncia de la noche de un palabra y jardín de las antes de la de la canda de insumero al especio se otro en inmimirian de la pierta de es la creció el casa de las tres podías pronusciso provemos de la
# scerencia en la espraría lo primera la banda de la cara de la intrabar propónica
# preveraga n

# %%
model.save(r'C:\Users\agusm\Documents\borgesSimpleModel.keras')
